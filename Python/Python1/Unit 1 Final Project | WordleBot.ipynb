# %% [markdown]
# # Wordlebot
# For your unit 1 final project we're going to create a wordlebot. Wordlebot is going to require everything you've learned so far: lists, strings, arrays, dictionaries and functions. It can be a little tricky, so you're free to work together with others. However, you have to write your own solution.
#
# You can make wordlebot any way you want, but I'm going to give you an outline below that should make things a little easier.
#
# ## Get WordleWords
# To build a wordlebot we're going to need to have all the words that are  allowed in wordle. Fortunately fo us, Donald Knuth at Stanford has published a handy list of 5 letter words that we can grab off the web.

# %%
from urllib import request
import random

def getwordlewords():
    wurl = "https://www-cs-faculty.stanford.edu/~knuth/sgb-words.txt"
    page = request.urlopen(wurl)
    _bytes = page.read()
    wordlist = _bytes.decode('utf-8')
    words = wordlist.split('\n')
    return words

# %% [markdown]
# You dont need to understand everyting in getwordlwords() at this point, but its useful to understand whats going on.
# In the first line
# ```wurl = "https://www-cs-faculty.stanford.edu/~knuth/sgb-words.txt"```
# we're just writing a web URL as a string. Copy that into a browser url and take a look ... its all the wordle words! We could just copy that into an array but that would get pretty messy, so istead we'll just scrape it off the webpage. You'll notice that we imported request in the first line (```from urllib import request```) -- this gives us tools to open webpages in pything.
#
# The second line
#
# ```page = request.urlopen(wurl)```
#
# Opens the URL in python.
#
# The third line
#
# ```_bytes = page.read()```
#
# reads all the information on that URL in bytes into a variable called, not surprisingly, bytes. Its tricky to read bytes if you're not a computer so we need to transform that data into text. We do this with
# ```wordlist = bytes.decode('utf-8')```
# The ```utf-8``` variable tells python how the data was encoded. UTF-8 is the most  common standard that webpages are encoded, and the correct encoding for this specific webpage.
#
# Now we have one large string that has all the wordlewords in which each word is seperated by a special character called a 'newline', given by '\n'. If you were to print it out at this point the first few characters might look like
#
# 'apple\namore\nalive\n ... '
#
# We can turn this into a list by splitting it on each newlinecharacter, which we do by calling
#
# ```words = wordlist.split('\n')```
#
# Which is returned. And Viola! we havea  list of all the wordle words. Lets try it out.

# %%
words = getwordlewords()
words
# Out:
# ['which',
#  'there',
#  'their',
#  'about',
#  'would',
#  'these',
#  'other',
#  'words',
#  'could',
#  'write',
#  'first',
#  'water',
#  'after',
#  'where',
#  'right',
#  'think',
#  'three',
#  'years',
#  'place',
#  'sound',
#  'great',
#  'again',
#  'still',
#  'every',
#  'small',
#  'found',
#  'those',
#  'never',
#  'under',
#  'might',
#  'while',
#  'house',
#  'world',
#  'below',
#  'asked',
#  'going',
#  'large',
#  'until',
#  'along',
#  'shall',
#  'being',
#  'often',
#  'earth',
#  'began',
#  'since',
#  'study',
#  'night',
#  'light',
#  'above',
#  'paper',
#  'parts',
#  'young',
#  'story',
#  'point',
#  'times',
#  'heard',
#  'whole',
#  'white',
#  'given',
#  'means',
#  'music',
#  'miles',
#  'thing',
#  'today',
#  'later',
#  'using',
#  'money',
#  'lines',
#  'order',
#  'group',
#  'among',
#  'learn',
#  'known',
#  'space',
#  'table',
#  'early',
#  'trees',
#  'short',
#  'hands',
#  'state',
#  'black',
#  'shown',
#  'stood',
#  'front',
#  'voice',
#  'kinds',
#  'makes',
#  'comes',
#  'close',
#  'power',
#  'lived',
#  'vowel',
#  'taken',
#  'built',
#  'heart',
#  'ready',
#  'quite',
#  'class',
#  'bring',
#  'round',
#  'horse',
#  'shows',
#  'piece',
#  'green',
#  'stand',
#  'birds',
#  'start',
#  'river',
#  'tried',
#  'least',
#  'field',
#  'whose',
#  'girls',
#  'leave',
#  'added',
#  'color',
#  'third',
#  'hours',
#  'moved',
#  'plant',
#  'doing',
#  'names',
#  'forms',
#  'heavy',
#  'ideas',
#  'cried',
#  'check',
#  'floor',
#  'begin',
#  'woman',
#  'alone',
#  'plane',
#  'spell',
#  'watch',
#  'carry',
#  'wrote',
#  'clear',
#  'named',
#  'books',
#  'child',
#  'glass',
#  'human',
#  'takes',
#  'party',
#  'build',
#  'seems',
#  'blood',
#  'sides',
#  'seven',
#  'mouth',
#  'solve',
#  'north',
#  'value',
#  'death',
#  'maybe',
#  'happy',
#  'tells',
#  'gives',
#  'looks',
#  'shape',
#  'lives',
#  'steps',
#  'areas',
#  'sense',
#  'speak',
#  'force',
#  'ocean',
#  'speed',
#  'women',
#  'metal',
#  'south',
#  'grass',
#  'scale',
#  'cells',
#  'lower',
#  'sleep',
#  'wrong',
#  'pages',
#  'ships',
#  'needs',
#  'rocks',
#  'eight',
#  'major',
#  'level',
#  'total',
#  'ahead',
#  'reach',
#  'stars',
#  'store',
#  'sight',
#  'terms',
#  'catch',
#  'works',
#  'board',
#  'cover',
#  'songs',
#  'equal',
#  'stone',
#  'waves',
#  'guess',
#  'dance',
#  'spoke',
#  'break',
#  'cause',
#  'radio',
#  'weeks',
#  'lands',
#  'basic',
#  'liked',
#  'trade',
#  'fresh',
#  'final',
#  'fight',
#  'meant',
#  'drive',
#  'spent',
#  'local',
#  'waxes',
#  'knows',
#  'train',
#  'bread',
#  'homes',
#  'teeth',
#  'coast',
#  'thick',
#  'brown',
#  'clean',
#  'quiet',
#  'sugar',
#  'facts',
#  'steel',
#  'forth',
#  'rules',
#  'notes',
#  'units',
#  'peace',
#  'month',
#  'verbs',
#  'seeds',
#  'helps',
#  'sharp',
#  'visit',
#  'woods',
#  'chief',
#  'walls',
#  'cross',
#  'wings',
#  'grown',
#  'cases',
#  'foods',
#  'crops',
#  'fruit',
#  'stick',
#  'wants',
#  'stage',
#  'sheep',
#  'nouns',
#  'plain',
#  'drink',
#  'bones',
#  'apart',
#  'turns',
#  'moves',
#  'touch',
#  'angle',
#  'based',
#  'range',
#  'marks',
#  'tired',
#  'older',
#  'farms',
#  'spend',
#  'shoes',
#  'goods',
#  'chair',
#  'twice',
#  'cents',
#  'empty',
#  'alike',
#  'style',
#  'broke',
#  'pairs',
#  'count',
#  'enjoy',
#  'score',
#  'shore',
#  'roots',
#  'paint',
#  'heads',
#  'shook',
#  'serve',
#  'angry',
#  'crowd',
#  'wheel',
#  'quick',
#  'dress',
#  'share',
#  'alive',
#  'noise',
#  'solid',
#  'cloth',
#  'signs',
#  'hills',
#  'types',
#  'drawn',
#  'worth',
#  'truck',
#  'piano',
#  'upper',
#  'loved',
#  'usual',
#  'faces',
#  'drove',
#  'cabin',
#  'boats',
#  'towns',
#  'proud',
#  'court',
#  'model',
#  'prime',
#  'fifty',
#  'plans',
#  'yards',
#  'prove',
#  'tools',
#  'price',
#  'sheet',
#  'smell',
#  'boxes',
#  'raise',
#  'match',
#  'truth',
#  'roads',
#  'threw',
#  'enemy',
#  'lunch',
#  'chart',
#  'scene',
#  'graph',
#  'doubt',
#  'guide',
#  'winds',
#  'block',
#  'grain',
#  'smoke',
#  'mixed',
#  'games',
#  'wagon',
#  'sweet',
#  'topic',
#  'extra',
#  'plate',
#  'title',
#  'knife',
#  'fence',
#  'falls',
#  'cloud',
#  'wheat',
#  'plays',
#  'enter',
#  'broad',
#  'steam',
#  'atoms',
#  'press',
#  'lying',
#  'basis',
#  'clock',
#  'taste',
#  'grows',
#  'thank',
#  'storm',
#  'agree',
#  'brain',
#  'track',
#  'smile',
#  'funny',
#  'beach',
#  'stock',
#  'hurry',
#  'saved',
#  'sorry',
#  'giant',
#  'trail',
#  'offer',
#  'ought',
#  'rough',
#  'daily',
#  'avoid',
#  'keeps',
#  'throw',
#  'allow',
#  'cream',
#  'laugh',
#  'edges',
#  'teach',
#  'frame',
#  'bells',
#  'dream',
#  'magic',
#  'occur',
#  'ended',
#  'chord',
#  'false',
#  'skill',
#  'holes',
#  'dozen',
#  'brave',
#  'apple',
#  'climb',
#  'outer',
#  'pitch',
#  'ruler',
#  'holds',
#  'fixed',
#  'costs',
#  'calls',
#  'blank',
#  'staff',
#  'labor',
#  'eaten',
#  'youth',
#  'tones',
#  'honor',
#  'globe',
#  'gases',
#  'doors',
#  'poles',
#  'loose',
#  'apply',
#  'tears',
#  'exact',
#  'brush',
#  'chest',
#  'layer',
#  'whale',
#  'minor',
#  'faith',
#  'tests',
#  'judge',
#  'items',
#  'worry',
#  'waste',
#  'hoped',
#  'strip',
#  'begun',
#  'aside',
#  'lakes',
#  'bound',
#  'depth',
#  'candy',
#  'event',
#  'worse',
#  'aware',
#  'shell',
#  'rooms',
#  'ranch',
#  'image',
#  'snake',
#  'aloud',
#  'dried',
#  'likes',
#  'motor',
#  'pound',
#  'knees',
#  'refer',
#  'fully',
#  'chain',
#  'shirt',
#  'flour',
#  'drops',
#  'spite',
#  'orbit',
#  'banks',
#  'shoot',
#  'curve',
#  'tribe',
#  'tight',
#  'blind',
#  'slept',
#  'shade',
#  'claim',
#  'flies',
#  'theme',
#  'queen',
#  'fifth',
#  'union',
#  'hence',
#  'straw',
#  'entry',
#  'issue',
#  'birth',
#  'feels',
#  'anger',
#  'brief',
#  'rhyme',
#  'glory',
#  'guard',
#  'flows',
#  'flesh',
#  'owned',
#  'trick',
#  'yours',
#  'sizes',
#  'noted',
#  'width',
#  'burst',
#  'route',
#  'lungs',
#  'uncle',
#  'bears',
#  'royal',
#  'kings',
#  'forty',
#  'trial',
#  'cards',
#  'brass',
#  'opera',
#  'chose',
#  'owner',
#  'vapor',
#  'beats',
#  'mouse',
#  'tough',
#  'wires',
#  'meter',
#  'tower',
#  'finds',
#  'inner',
#  'stuck',
#  'arrow',
#  'poems',
#  'label',
#  'swing',
#  'solar',
#  'truly',
#  'tense',
#  'beans',
#  'split',
#  'rises',
#  'weigh',
#  'hotel',
#  'stems',
#  'pride',
#  'swung',
#  'grade',
#  'digit',
#  'badly',
#  'boots',
#  'pilot',
#  'sales',
#  'swept',
#  'lucky',
#  'prize',
#  'stove',
#  'tubes',
#  'acres',
#  'wound',
#  'steep',
#  'slide',
#  'trunk',
#  'error',
#  'porch',
#  'slave',
#  'exist',
#  'faced',
#  'mines',
#  'marry',
#  'juice',
#  'raced',
#  'waved',
#  'goose',
#  'trust',
#  'fewer',
#  'favor',
#  'mills',
#  'views',
#  'joint',
#  'eager',
#  'spots',
#  'blend',
#  'rings',
#  'adult',
#  'index',
#  'nails',
#  'horns',
#  'balls',
#  'flame',
#  'rates',
#  'drill',
#  'trace',
#  'skins',
#  'waxed',
#  'seats',
#  'stuff',
#  'ratio',
#  'minds',
#  'dirty',
#  'silly',
#  'coins',
#  'hello',
#  'trips',
#  'leads',
#  'rifle',
#  'hopes',
#  'bases',
#  'shine',
#  'bench',
#  'moral',
#  'fires',
#  'meals',
#  'shake',
#  'shops',
#  'cycle',
#  'movie',
#  'slope',
#  'canoe',
#  'teams',
#  'folks',
#  'fired',
#  'bands',
#  'thumb',
#  'shout',
#  'canal',
#  'habit',
#  'reply',
#  'ruled',
#  'fever',
#  'crust',
#  'shelf',
#  'walks',
#  'midst',
#  'crack',
#  'print',
#  'tales',
#  'coach',
#  'stiff',
#  'flood',
#  'verse',
#  'awake',
#  'rocky',
#  'march',
#  'fault',
#  'swift',
#  'faint',
#  'civil',
#  'ghost',
#  'feast',
#  'blade',
#  'limit',
#  'germs',
#  'reads',
#  'ducks',
#  'dairy',
#  'worst',
#  'gifts',
#  'lists',
#  'stops',
#  'rapid',
#  'brick',
#  'claws',
#  'beads',
#  'beast',
#  'skirt',
#  'cakes',
#  'lions',
#  'frogs',
#  'tries',
#  'nerve',
#  'grand',
#  'armed',
#  'treat',
#  'honey',
#  'moist',
#  'legal',
#  'penny',
#  'crown',
#  'shock',
#  'taxes',
#  'sixty',
#  'altar',
#  'pulls',
#  'sport',
#  'drums',
#  'talks',
#  'dying',
#  'dates',
#  'drank',
#  'blows',
#  'lever',
#  'wages',
#  'proof',
#  'drugs',
#  'tanks',
#  'sings',
#  'tails',
#  'pause',
#  'herds',
#  'arose',
#  'hated',
#  'clues',
#  'novel',
#  'shame',
#  'burnt',
#  'races',
#  'flash',
#  'weary',
#  'heels',
#  'token',
#  'coats',
#  'spare',
#  'shiny',
#  'alarm',
#  'dimes',
#  'sixth',
#  'clerk',
#  'mercy',
#  'sunny',
#  'guest',
#  'float',
#  'shone',
#  'pipes',
#  'worms',
#  'bills',
#  'sweat',
#  'suits',
#  'smart',
#  'upset',
#  'rains',
#  'sandy',
#  'rainy',
#  'parks',
#  'sadly',
#  'fancy',
#  'rider',
#  'unity',
#  'bunch',
#  'rolls',
#  'crash',
#  'craft',
#  'newly',
#  'gates',
#  'hatch',
#  'paths',
#  'funds',
#  'wider',
#  'grace',
#  'grave',
#  'tides',
#  'admit',
#  'shift',
#  'sails',
#  'pupil',
#  'tiger',
#  'angel',
#  'cruel',
#  'agent',
#  'drama',
#  'urged',
#  'patch',
#  'nests',
#  'vital',
#  'sword',
#  'blame',
#  'weeds',
#  'screw',
#  'vocal',
#  'bacon',
#  'chalk',
#  'cargo',
#  'crazy',
#  'acted',
#  'goats',
#  'arise',
#  'witch',
#  'loves',
#  'queer',
#  'dwell',
#  'backs',
#  'ropes',
#  'shots',
#  'merry',
#  'phone',
#  'cheek',
#  'peaks',
#  'ideal',
#  'beard',
#  'eagle',
#  'creek',
#  'cries',
#  'ashes',
#  'stall',
#  'yield',
#  'mayor',
#  'opens',
#  'input',
#  'fleet',
#  'tooth',
#  'cubic',
#  'wives',
#  'burns',
#  'poets',
#  'apron',
#  'spear',
#  'organ',
#  'cliff',
#  'stamp',
#  'paste',
#  'rural',
#  'baked',
#  'chase',
#  'slice',
#  'slant',
#  'knock',
#  'noisy',
#  'sorts',
#  'stays',
#  'wiped',
#  'blown',
#  'piled',
#  'clubs',
#  'cheer',
#  'widow',
#  'twist',
#  'tenth',
#  'hides',
#  'comma',
#  'sweep',
#  'spoon',
#  'stern',
#  'crept',
#  'maple',
#  'deeds',
#  'rides',
#  'muddy',
#  'crime',
#  'jelly',
#  'ridge',
#  'drift',
#  'dusty',
#  'devil',
#  'tempo',
#  'humor',
#  'sends',
#  'steal',
#  'tents',
#  'waist',
#  'roses',
#  'reign',
#  'noble',
#  'cheap',
#  'dense',
#  'linen',
#  'geese',
#  'woven',
#  'posts',
#  'hired',
#  'wrath',
#  'salad',
#  'bowed',
#  'tires',
#  'shark',
#  'belts',
#  'grasp',
#  'blast',
#  'polar',
#  'fungi',
#  'tends',
#  'pearl',
#  'loads',
#  'jokes',
#  'veins',
#  'frost',
#  'hears',
#  'loses',
#  'hosts',
#  'diver',
#  'phase',
#  'toads',
#  'alert',
#  'tasks',
#  'seams',
#  'coral',
#  'focus',
#  'naked',
#  'puppy',
#  'jumps',
#  'spoil',
#  'quart',
#  'macro',
#  'fears',
#  'flung',
#  'spark',
#  'vivid',
#  'brook',
#  'steer',
#  'spray',
#  'decay',
#  'ports',
#  'socks',
#  'urban',
#  'goals',
#  'grant',
#  'minus',
#  'films',
#  'tunes',
#  'shaft',
#  'firms',
#  'skies',
#  'bride',
#  'wreck',
#  'flock',
#  'stare',
#  'hobby',
#  'bonds',
#  'dared',
#  'faded',
#  'thief',
#  'crude',
#  'pants',
#  'flute',
#  'votes',
#  'tonal',
#  'radar',
#  'wells',
#  'skull',
#  'hairs',
#  'argue',
#  'wears',
#  'dolls',
#  'voted',
#  'caves',
#  'cared',
#  'broom',
#  'scent',
#  'panel',
#  'fairy',
#  'olive',
#  'bends',
#  'prism',
#  'lamps',
#  'cable',
#  'peach',
#  'ruins',
#  'rally',
#  'schwa',
#  'lambs',
#  'sells',
#  'cools',
#  'draft',
#  'charm',
#  'limbs',
#  'brake',
#  'gazed',
#  'cubes',
#  'delay',
#  'beams',
#  'fetch',
#  'ranks',
#  'array',
#  'harsh',
#  'camel',
#  'vines',
#  'picks',
#  'naval',
#  'purse',
#  'rigid',
#  'crawl',
#  'toast',
#  'soils',
#  'sauce',
#  'basin',
#  'ponds',
#  'twins',
#  'wrist',
#  'fluid',
#  'pools',
#  'brand',
#  'stalk',
#  'robot',
#  'reeds',
#  'hoofs',
#  'buses',
#  'sheer',
#  'grief',
#  'bloom',
#  'dwelt',
#  'melts',
#  'risen',
#  'flags',
#  'knelt',
#  'fiber',
#  'roofs',
#  'freed',
#  'armor',
#  'piles',
#  'aimed',
#  'algae',
#  'twigs',
#  'lemon',
#  'ditch',
#  ...]

# %% [markdown]
# Great! Now we have the wordle words. To make a wordle bot we're going to need to make several functions and then chain them all together into a program. I've stubbed out one potentail soltuion below.  You need to fill in the details.

# %%
class Worlde:
    
    def __init__(self, word=None, wordlist=None):
        
        if wordlist == None: 
            wordlist = "knuth"
        self.wordlist =

# %%
class WorldleSolver:
    
    def __init__(self, wordlist=None):
        
        
        
        # worle datastructures. Green is correct letter, correct place. Yellow is correct letter
        # incorrect place. Grey is wrong letter.
        self.guesses = []
        self.green = {} # right letter right place 
        self.yellow = {} # right letter wrong place 
        self.black = "" # wrong letter 
        
    def get_wordle_words(self, wordlist=None):
        # gets a list of all possible worlde words
        

        if wordlist == None or wordlist=='knuth':
            wurl = "https://www-cs-faculty.stanford.edu/~knuth/sgb-words.txt"
            page = request.urlopen(wurl)
            _bytes = page.read()
            wordlist = _bytes.decode('utf-8')
            words = wordlist.split('\n')
            return words
        else:
            raise Exception("unknown wordlist")
    
    def clean_input(self, s):
        s = s.lower().strip()
        allowed = "abcdefghijklmnopqrstuvwxyz"
        for l in s: 
            if l not in allowed: 
                raise Exception("Unknown symbol in word: %s"%l)
        if len(s) != 5: 
            raise Exception("guesses must be 5 characters")
        return s
    
    def map_input(self, s, color_feedback):
        '''
        Color feedback comes from the app. Its g (green), y (yellow), or b (black)
        
        So if the word was  "baste"
        and my guess was    "break"
        
        color feedback would be: "gbybb"
        If you're playing NYT wordle, all you need to do is put in your guess and  
        '''
        
        try:
            s = self.clean_input(s)
        except Exception as e:
            print(e)
            return -1
        
        # check for unique
        if s in self.guesses: 
            print("You've already guessed %s"%s)
            return -1
        
        # add to guesses 
        self.guesses.append(s)
        
         


def green_squares(guess, solution, previous_greens=None):
    '''
    returns a dictionary showing correct letter correct place for a guess relative to a solution (e.g. green
    squares in wordle)
    '''
    
    green = {
        0: None,
        1: None,
        2: None,
        3: None,
        4: None
    }
    
    ''' 
    NOTE: the above is the base dictionary. If the solution word was "trace" and your guess was "there" 
    the dictionary entry for 0 would be "t" and 4 would be "e". 
    
    NOTE2: Remember that the first letter is 0 and not 1.
    
    NOTE3: last_rlrp is the rlrp information from previous guesses. For the first guess it will be None so 
    you can ignore it, but for future guesses you'll want to add it into the dictionary.  
    '''
    
    
    ## your code here
    return green

# %%
def yellow_squares(guess, solution, previous_yellows): 
    '''
    Returns a dictionary containing all the right letter wrong place 
    '''
    
    yellow = {
        0: [],
        1: [],
        2: [],
        3: [],
        4: []
    }
    
    """Fill each array with all the letters in that position that were yellow. E.G. if the hidden word was trace
    and the guess was great you should have:
    
        # lining them up so they are easier to see
        trace
        great
    
    rlwp = {
        0: [],
        1: [],
        2: [e],
        3: [a],
        4: [t]
    }
    
    NOTE: You can put more than one letter in a box. For example: 0:[a,t] would mean both a and t were found
    to be yellow squares for the first position. 
    
    """
    return yellow

# %%
def black_squares(guess, solution, previous_blacks):
    '''
    Returns all the wrong letters (letters guessed that were not found in the word
    '''
    
    blacks = []
    
    # make this better 
    return blacks

# %%
def get_potentail_words(greens, yellows, blacks):
    '''
    Returns a list of every possible word given what we know. 
    
    INPUT: 
    Greens, Yellows and Blacks from the functions above. 
    
    '''
    
    # this just returns all potenail words as potential words. 
    # Its not great -- get rid of this and update the code to be better. 
    return getwordlewords()

# %%
def next_guess(potential_words, data=None):
    '''
    given a list of potential words it choses the next guess.
    
    This is where you're going to want to get creative. Which word should it chose? 
    Hint. Use get potential words to decide which word will eliminate the most words. 
    
    NOTE: you dont have to pick from potential words. You can get the wordlewords using the function above,
    or pass in the greens, blacks, and yellows or any other data in the data object. 
    '''
    
    # this line just choses a random next word. Its not great. Get rid of this and add your code
    idx = random.randint(1,len(potential_words))-1
    return potential_words[idx]

# %% [markdown]
# ## Play Wordle
# The following code basically runs a worldle simulator. It uses your functions above to run a world game and outputs statistics.

# %%
def play_wordle(solution, starting_word=None, n_attempts_allowed=6, words=None, verbose=False):

    if words == None: 
        potential_words = getwordlewords()
    
    scorecard = {
        'completed': False,
        'n_steps': 6,
        'guesses': [],
        'solution': solution
    }
    
    n_attempts = 0
    while n_attempts < n_attempts_allowed:
        
        # use the starting word if desired or guess a new one
        if n_attempts == 0 and starting_word != None:
            guess = starting_word
        else:
            guess = next_guess(potential_words)
        
        # record the guess and increment steps
        scorecard['guesses'].append(guess)
        n_attempts += 1
        
        # if correct return the successful results
        if guess == solution:
            scorecard['completed'] = True
            scorecard['n_steps'] = n_attempts
            scorecard['guesses'].append(guess)
            return scorecard
        
    return scorecard

# %%
solution = "digit"
play_wordle(solution, "queue")
# Out:
# {'completed': False,
#  'n_steps': 6,
#  'guesses': ['queue', 'stack', 'acted', 'drily', 'bebug', 'thats'],
#  'solution': 'digit'}

# %%
def play_lots_of_wordle(n_games, wordlist, starting_word=None, verbose=False):
    '''
    Play a large number of wordle games and record the score
    '''
    completed = 0
    failed = 0
    
    for i in range(n_games):
    
        # pick a random solution
        idx = random.randint(1,len(wordlist))-1
        solution = wordlist[idx]
        
        # play some wordle
        sc = play_wordle(solution)
        if sc['completed'] == True: 
            completed += 1
            if verbose: 
                print("Succeeded at finding %s in %d tries"%(sc['solution'], sc['n_steps']))
        else: failed += 1
        if verbose: 
            print("Failed at finding %s in %d tries"%(sc['solution'], sc['n_steps']))
    
    print("Completed: %d | Failed: %d | success_rate: %f"%(completed, failed, completed/(completed + failed*1.0)))

play_lots_of_wordle(100, getwordlewords(), 'queue', verbose=True)
# Out:
# Failed at finding oiled in 6 tries
# Failed at finding mends in 6 tries
# Failed at finding patio in 6 tries
# Failed at finding hussy in 6 tries
# Failed at finding schmo in 6 tries
# Failed at finding bolos in 6 tries
# Failed at finding pizza in 6 tries
# Failed at finding jails in 6 tries
# Failed at finding finds in 6 tries
# Succeeded at finding baste in 5 tries
# Failed at finding baste in 5 tries
# Failed at finding bider in 6 tries
# Failed at finding coons in 6 tries
# Failed at finding dinks in 6 tries
# Failed at finding goody in 6 tries
# Failed at finding femme in 6 tries
# Failed at finding hires in 6 tries
# Failed at finding finch in 6 tries
# Failed at finding chews in 6 tries
# Failed at finding hosts in 6 tries
# Failed at finding wiped in 6 tries
# Failed at finding glary in 6 tries
# Failed at finding unapt in 6 tries
# Failed at finding plied in 6 tries
# Failed at finding deals in 6 tries
# Failed at finding bhang in 6 tries
# Failed at finding realm in 6 tries
# Failed at finding ounce in 6 tries
# Failed at finding napes in 6 tries
# Failed at finding toast in 6 tries
# Failed at finding hippo in 6 tries
# Failed at finding tubed in 6 tries
# Failed at finding gills in 6 tries
# Failed at finding robot in 6 tries
# Failed at finding court in 6 tries
# Failed at finding duper in 6 tries
# Failed at finding until in 6 tries
# Failed at finding shirr in 6 tries
# Failed at finding hired in 6 tries
# Failed at finding asana in 6 tries
# Failed at finding choke in 6 tries
# Failed at finding rebar in 6 tries
# Failed at finding sedgy in 6 tries
# Failed at finding fussy in 6 tries
# Failed at finding gonna in 6 tries
# Failed at finding clerk in 6 tries
# Failed at finding badge in 6 tries
# Failed at finding daddy in 6 tries
# Failed at finding prats in 6 tries
# Failed at finding imago in 6 tries
# Failed at finding shirr in 6 tries
# Failed at finding elder in 6 tries
# Failed at finding demur in 6 tries
# Failed at finding daubs in 6 tries
# Failed at finding ganef in 6 tries
# Failed at finding slams in 6 tries
# Failed at finding faker in 6 tries
# Failed at finding light in 6 tries
# Failed at finding girts in 6 tries
# Failed at finding colts in 6 tries
# Failed at finding lefts in 6 tries
# Failed at finding cabby in 6 tries
# Failed at finding hated in 6 tries
# Failed at finding lance in 6 tries
# Failed at finding tempt in 6 tries
# Failed at finding slush in 6 tries
# Failed at finding vogue in 6 tries
# Failed at finding piker in 6 tries
# Failed at finding algae in 6 tries
# Failed at finding fully in 6 tries
# Failed at finding unfit in 6 tries
# Failed at finding diary in 6 tries
# Failed at finding dully in 6 tries
# Failed at finding doest in 6 tries
# Failed at finding shame in 6 tries
# Failed at finding digit in 6 tries
# Failed at finding shark in 6 tries
# Failed at finding laver in 6 tries
# Failed at finding sicko in 6 tries
# Failed at finding pluck in 6 tries
# Failed at finding limby in 6 tries
# Failed at finding ocher in 6 tries
# Failed at finding smuts in 6 tries
# Failed at finding stink in 6 tries
# Failed at finding lists in 6 tries
# Failed at finding ninth in 6 tries
# Failed at finding leach in 6 tries
# Failed at finding gauze in 6 tries
# Failed at finding noble in 6 tries
# Failed at finding globs in 6 tries
# Failed at finding quays in 6 tries
# Failed at finding kiddo in 6 tries
# Failed at finding heady in 6 tries
# Failed at finding bosom in 6 tries
# Failed at finding tenon in 6 tries
# Failed at finding toque in 6 tries
# Failed at finding racks in 6 tries
# Failed at finding mavis in 6 tries
# Failed at finding maxim in 6 tries
# Failed at finding debug in 6 tries
# Failed at finding mylar in 6 tries
# Failed at finding rebar in 6 tries
# Failed at finding props in 6 tries
# Failed at finding chock in 6 tries
# Failed at finding skies in 6 tries
# Failed at finding pussy in 6 tries
# Failed at finding rooms in 6 tries
# Failed at finding rapid in 6 tries
# Failed at finding humps in 6 tries
# Failed at finding inapt in 6 tries
# Failed at finding luxes in 6 tries
# Failed at finding waifs in 6 tries
# Failed at finding imams in 6 tries
# Failed at finding salon in 6 tries
# Failed at finding alway in 6 tries
# Failed at finding yells in 6 tries
# Failed at finding pearl in 6 tries
# Failed at finding atone in 6 tries
# Failed at finding carer in 6 tries
# Failed at finding angel in 6 tries
# Failed at finding bound in 6 tries
# Failed at finding thorn in 6 tries
# Failed at finding kiwis in 6 tries
# Failed at finding users in 6 tries
# Failed at finding totem in 6 tries
# Failed at finding avers in 6 tries
# Failed at finding trims in 6 tries
# Failed at finding sings in 6 tries
# Failed at finding tally in 6 tries
# Failed at finding teams in 6 tries
# Failed at finding volts in 6 tries
# Failed at finding smote in 6 tries
# Failed at finding rhino in 6 tries
# Failed at finding damns in 6 tries
# Failed at finding sixes in 6 tries
# Failed at finding homer in 6 tries
# Failed at finding carny in 6 tries
# Failed at finding aleph in 6 tries
# Failed at finding thing in 6 tries
# Failed at finding pesto in 6 tries
# Failed at finding leapt in 6 tries
# Failed at finding frizz in 6 tries
# Failed at finding enter in 6 tries
# Failed at finding fluke in 6 tries
# Failed at finding stuff in 6 tries
# Failed at finding marks in 6 tries
# Failed at finding cream in 6 tries
# Failed at finding terce in 6 tries
# Failed at finding fakes in 6 tries
# Failed at finding argot in 6 tries
# Failed at finding dated in 6 tries
# Failed at finding reaps in 6 tries
# Failed at finding riced in 6 tries
# Failed at finding porks in 6 tries
# Failed at finding genie in 6 tries
# Failed at finding pilau in 6 tries
# Failed at finding mimes in 6 tries
# Failed at finding stoup in 6 tries
# Failed at finding firth in 6 tries
# Failed at finding wharf in 6 tries
# Failed at finding filet in 6 tries
# Failed at finding polka in 6 tries
# Failed at finding adzes in 6 tries
# Failed at finding mitts in 6 tries
# Failed at finding sport in 6 tries
# Failed at finding ounce in 6 tries
# Failed at finding polly in 6 tries
# Failed at finding cough in 6 tries
# Failed at finding dumps in 6 tries
# Failed at finding funky in 6 tries
# Failed at finding gigas in 6 tries
# Failed at finding yelps in 6 tries
# Failed at finding sever in 6 tries
# Failed at finding ankle in 6 tries
# Failed at finding colts in 6 tries
# Failed at finding spate in 6 tries
# Failed at finding dwell in 6 tries
# Failed at finding scrum in 6 tries
# Failed at finding fauns in 6 tries
# Failed at finding snail in 6 tries
# Failed at finding jibed in 6 tries
# Failed at finding asker in 6 tries
# Failed at finding reaps in 6 tries
# Failed at finding lubes in 6 tries
# Failed at finding rewed in 6 tries
# Failed at finding sited in 6 tries
# Failed at finding riven in 6 tries
# Failed at finding gronk in 6 tries
# Failed at finding fails in 6 tries
# Failed at finding brags in 6 tries
# Failed at finding cooks in 6 tries
# Failed at finding unapt in 6 tries
# Failed at finding clams in 6 tries
# Failed at finding trams in 6 tries
# Failed at finding whomp in 6 tries
# Failed at finding foxed in 6 tries
# Failed at finding muggy in 6 tries
# Failed at finding lower in 6 tries
# Failed at finding newer in 6 tries
# Failed at finding endow in 6 tries
# Failed at finding wryly in 6 tries
# Failed at finding balms in 6 tries
# Failed at finding muggy in 6 tries
# Failed at finding lumps in 6 tries
# Failed at finding genus in 6 tries
# Failed at finding jiffs in 6 tries
# Failed at finding gills in 6 tries
# Failed at finding recto in 6 tries
# Failed at finding eyers in 6 tries
# Failed at finding admit in 6 tries
# Failed at finding steer in 6 tries
# Failed at finding goods in 6 tries
# Failed at finding usage in 6 tries
# Failed at finding ferny in 6 tries
# Failed at finding burps in 6 tries
# Failed at finding entry in 6 tries
# Failed at finding inner in 6 tries
# Failed at finding reedy in 6 tries
# Failed at finding esses in 6 tries
# Failed at finding peens in 6 tries
# Failed at finding slash in 6 tries
# Failed at finding yawns in 6 tries
# Failed at finding brace in 6 tries
# Failed at finding loser in 6 tries
# Failed at finding rebid in 6 tries
# Failed at finding slake in 6 tries
# Failed at finding dares in 6 tries
# Failed at finding about in 6 tries
# Failed at finding latin in 6 tries
# Failed at finding morns in 6 tries
# Failed at finding thick in 6 tries
# Failed at finding fetal in 6 tries
# Failed at finding gimps in 6 tries
# Failed at finding pared in 6 tries
# Failed at finding topic in 6 tries
# Failed at finding loves in 6 tries
# Failed at finding skate in 6 tries
# Failed at finding tunes in 6 tries
# Failed at finding genre in 6 tries
# Failed at finding riots in 6 tries
# Failed at finding pulps in 6 tries
# Failed at finding vetch in 6 tries
# Failed at finding vibes in 6 tries
# Failed at finding molls in 6 tries
# Failed at finding memes in 6 tries
# Failed at finding matey in 6 tries
# Failed at finding grads in 6 tries
# Failed at finding jingo in 6 tries
# Failed at finding anvil in 6 tries
# Failed at finding spoke in 6 tries
# Failed at finding blown in 6 tries
# Failed at finding doser in 6 tries
# Failed at finding lurer in 6 tries
# Failed at finding pates in 6 tries
# Failed at finding flier in 6 tries
# Failed at finding duomo in 6 tries
# Failed at finding yogas in 6 tries
# Failed at finding afore in 6 tries
# Failed at finding drift in 6 tries
# Failed at finding unlit in 6 tries
# Failed at finding first in 6 tries
# Failed at finding cleft in 6 tries
# Failed at finding deque in 6 tries
# Failed at finding adult in 6 tries
# Failed at finding spina in 6 tries
# Failed at finding plash in 6 tries
# Failed at finding yobbo in 6 tries
# Failed at finding alert in 6 tries
# Failed at finding stele in 6 tries
# Failed at finding zests in 6 tries
# Failed at finding order in 6 tries
# Failed at finding ricer in 6 tries
# Failed at finding bench in 6 tries
# Failed at finding gourd in 6 tries
# Failed at finding gusto in 6 tries
# Failed at finding coils in 6 tries
# Failed at finding lease in 6 tries
# Failed at finding uncut in 6 tries
# Failed at finding whiff in 6 tries
# Failed at finding young in 6 tries
# Failed at finding cuppa in 6 tries
# Failed at finding skoal in 6 tries
# Failed at finding surds in 6 tries
# Failed at finding diddy in 6 tries
# Failed at finding bigot in 6 tries
# Failed at finding helps in 6 tries
# Failed at finding preys in 6 tries
# Failed at finding phase in 6 tries
# Failed at finding bulky in 6 tries
# Failed at finding pubes in 6 tries
# Failed at finding fichu in 6 tries
# Failed at finding hamza in 6 tries
# Failed at finding wills in 6 tries
# Failed at finding dribs in 6 tries
# Failed at finding barms in 6 tries
# Failed at finding viler in 6 tries
# Failed at finding erect in 6 tries
# Failed at finding arced in 6 tries
# Failed at finding okays in 6 tries
# Failed at finding rupee in 6 tries
# Failed at finding withs in 6 tries
# Failed at finding seest in 6 tries
# Failed at finding ovary in 6 tries
# Failed at finding timer in 6 tries
# Failed at finding surds in 6 tries
# Failed at finding maker in 6 tries
# Failed at finding rills in 6 tries
# Failed at finding taper in 6 tries
# Failed at finding noise in 6 tries
# Failed at finding kazoo in 6 tries
# Failed at finding loess in 6 tries
# Failed at finding coped in 6 tries
# Failed at finding ideal in 6 tries
# Failed at finding proms in 6 tries
# Failed at finding bauds in 6 tries
# Failed at finding clubs in 6 tries
# Failed at finding unapt in 6 tries
# Failed at finding hexad in 6 tries
# Failed at finding truce in 6 tries
# Failed at finding greps in 6 tries
# Failed at finding loves in 6 tries
# Failed at finding whews in 6 tries
# Failed at finding lippy in 6 tries
# Failed at finding tongs in 6 tries
# Failed at finding inure in 6 tries
# Failed at finding porgy in 6 tries
# Failed at finding wazoo in 6 tries
# Failed at finding beaut in 6 tries
# Failed at finding butts in 6 tries
# Failed at finding rigor in 6 tries
# Failed at finding rummy in 6 tries
# Failed at finding audio in 6 tries
# Failed at finding parka in 6 tries
# Failed at finding kebab in 6 tries
# Failed at finding waged in 6 tries
# Failed at finding nitty in 6 tries
# Failed at finding excel in 6 tries
# Failed at finding situs in 6 tries
# Failed at finding emits in 6 tries
# Failed at finding bebop in 6 tries
# Failed at finding flaps in 6 tries
# Failed at finding slyer in 6 tries
# Failed at finding bilgy in 6 tries
# Failed at finding rebel in 6 tries
# Failed at finding vegan in 6 tries
# Failed at finding ozone in 6 tries
# Failed at finding local in 6 tries
# Failed at finding livre in 6 tries
# Failed at finding money in 6 tries
# Failed at finding swell in 6 tries
# Failed at finding furry in 6 tries
# Failed at finding decal in 6 tries
# Failed at finding imply in 6 tries
# Failed at finding ethos in 6 tries
# Failed at finding nobly in 6 tries
# Failed at finding momma in 6 tries
# Failed at finding goads in 6 tries
# Failed at finding beeps in 6 tries
# Failed at finding yummy in 6 tries
# Failed at finding fatwa in 6 tries
# Failed at finding clink in 6 tries
# Failed at finding antes in 6 tries
# Failed at finding peeps in 6 tries
# Failed at finding chews in 6 tries
# Failed at finding slots in 6 tries
# Failed at finding cures in 6 tries
# Failed at finding greek in 6 tries
# Failed at finding dings in 6 tries
# Failed at finding peppy in 6 tries
# Failed at finding soaps in 6 tries
# Failed at finding brink in 6 tries
# Failed at finding crept in 6 tries
# Failed at finding enema in 6 tries
# Failed at finding yogas in 6 tries
# Failed at finding boric in 6 tries
# Failed at finding balds in 6 tries
# Failed at finding stack in 6 tries
# Failed at finding nooks in 6 tries
# Failed at finding zoned in 6 tries
# Failed at finding yukky in 6 tries
# Failed at finding lotsa in 6 tries
# Failed at finding badge in 6 tries
# Failed at finding nexus in 6 tries
# Failed at finding mixed in 6 tries
# Failed at finding casas in 6 tries
# Failed at finding ombre in 6 tries
# Failed at finding doles in 6 tries
# Failed at finding popes in 6 tries
# Failed at finding looky in 6 tries
# Failed at finding kapok in 6 tries
# Failed at finding baggy in 6 tries
# Failed at finding unban in 6 tries
# Failed at finding beady in 6 tries
# Failed at finding corms in 6 tries
# Failed at finding pikes in 6 tries
# Failed at finding edged in 6 tries
# Failed at finding ameba in 6 tries
# Failed at finding limed in 6 tries
# Failed at finding plumy in 6 tries
# Failed at finding umbel in 6 tries
# Failed at finding soups in 6 tries
# Failed at finding hairy in 6 tries
# Failed at finding stock in 6 tries
# Failed at finding warps in 6 tries
# Failed at finding cohos in 6 tries
# Failed at finding crave in 6 tries
# Failed at finding ogled in 6 tries
# Failed at finding muffs in 6 tries
# Failed at finding mambo in 6 tries
# Failed at finding chime in 6 tries
# Failed at finding howdy in 6 tries
# Failed at finding rayon in 6 tries
# Failed at finding algin in 6 tries
# Failed at finding onset in 6 tries
# Failed at finding greys in 6 tries
# Failed at finding lieth in 6 tries
# Failed at finding washy in 6 tries
# Failed at finding echos in 6 tries
# Failed at finding tulip in 6 tries
# Failed at finding basin in 6 tries
# Failed at finding novae in 6 tries
# Failed at finding debit in 6 tries
# Failed at finding poesy in 6 tries
# Failed at finding catch in 6 tries
# Failed at finding spark in 6 tries
# Failed at finding swung in 6 tries
# Failed at finding soupy in 6 tries
# Failed at finding moony in 6 tries
# Failed at finding hying in 6 tries
# Failed at finding steal in 6 tries
# Failed at finding brads in 6 tries
# Failed at finding slips in 6 tries
# Failed at finding firer in 6 tries
# Failed at finding slats in 6 tries
# Failed at finding hauls in 6 tries
# Failed at finding piper in 6 tries
# Failed at finding broth in 6 tries
# Failed at finding sepal in 6 tries
# Failed at finding green in 6 tries
# Failed at finding prose in 6 tries
# Failed at finding turns in 6 tries
# Failed at finding noise in 6 tries
# Failed at finding flume in 6 tries
# Failed at finding halve in 6 tries
# Failed at finding deads in 6 tries
# Failed at finding rivet in 6 tries
# Failed at finding junks in 6 tries
# Failed at finding slack in 6 tries
# Failed at finding quirk in 6 tries
# Failed at finding sizes in 6 tries
# Failed at finding palmy in 6 tries
# Failed at finding feign in 6 tries
# Failed at finding shied in 6 tries
# Failed at finding codex in 6 tries
# Failed at finding poise in 6 tries
# Failed at finding helms in 6 tries
# Failed at finding prima in 6 tries
# Failed at finding agave in 6 tries
# Failed at finding booze in 6 tries
# Failed at finding navel in 6 tries
# Failed at finding muxes in 6 tries
# Failed at finding rough in 6 tries
# Failed at finding iliac in 6 tries
# Failed at finding bones in 6 tries
# Failed at finding shark in 6 tries
# Failed at finding login in 6 tries
# Failed at finding twigs in 6 tries
# Failed at finding voids in 6 tries
# Failed at finding choir in 6 tries
# Failed at finding biles in 6 tries
# Failed at finding angel in 6 tries
# Failed at finding paces in 6 tries
# Failed at finding cents in 6 tries
# Failed at finding rondo in 6 tries
# Failed at finding mambo in 6 tries
# Failed at finding pluck in 6 tries
# Failed at finding tippy in 6 tries
# Failed at finding still in 6 tries
# Failed at finding adopt in 6 tries
# Failed at finding speed in 6 tries
# Failed at finding matzo in 6 tries
# Failed at finding parks in 6 tries
# Failed at finding sects in 6 tries
# Failed at finding tails in 6 tries
# Failed at finding drink in 6 tries
# Failed at finding brigs in 6 tries
# Failed at finding funny in 6 tries
# Failed at finding color in 6 tries
# Failed at finding pigmy in 6 tries
# Failed at finding keyer in 6 tries
# Failed at finding raved in 6 tries
# Failed at finding beads in 6 tries
# Failed at finding tower in 6 tries
# Failed at finding stand in 6 tries
# Failed at finding puppy in 6 tries
# Failed at finding fusty in 6 tries
# Failed at finding infra in 6 tries
# Failed at finding loser in 6 tries
# Failed at finding index in 6 tries
# Failed at finding whipt in 6 tries
# Failed at finding ruder in 6 tries
# Failed at finding known in 6 tries
# Failed at finding tulle in 6 tries
# Failed at finding parch in 6 tries
# Failed at finding pines in 6 tries
# Failed at finding acted in 6 tries
# Failed at finding meaty in 6 tries
# Failed at finding plash in 6 tries
# Failed at finding skiff in 6 tries
# Failed at finding spill in 6 tries
# Failed at finding noose in 6 tries
# Failed at finding staff in 6 tries
# Failed at finding groin in 6 tries
# Failed at finding silts in 6 tries
# Failed at finding caned in 6 tries
# Failed at finding mussy in 6 tries
# Failed at finding hater in 6 tries
# Failed at finding cubic in 6 tries
# Failed at finding wards in 6 tries
# Failed at finding tidal in 6 tries
# Failed at finding rites in 6 tries
# Failed at finding filet in 6 tries
# Failed at finding fauns in 6 tries
# Failed at finding peats in 6 tries
# Failed at finding frame in 6 tries
# Failed at finding alike in 6 tries
# Failed at finding flips in 6 tries
# Failed at finding raped in 6 tries
# Succeeded at finding plank in 2 tries
# Failed at finding plank in 2 tries
# Failed at finding nippy in 6 tries
# Failed at finding holly in 6 tries
# Failed at finding krona in 6 tries
# Failed at finding revel in 6 tries
# Failed at finding hayey in 6 tries
# Failed at finding bakes in 6 tries
# Failed at finding moxie in 6 tries
# Failed at finding token in 6 tries
# Failed at finding intro in 6 tries
# Failed at finding gaunt in 6 tries
# Failed at finding jives in 6 tries
# Failed at finding tromp in 6 tries
# Failed at finding mavis in 6 tries
# Failed at finding molly in 6 tries
# Failed at finding cuffs in 6 tries
# Failed at finding lyres in 6 tries
# Failed at finding kikes in 6 tries
# Failed at finding yokel in 6 tries
# Failed at finding tough in 6 tries
# Failed at finding strew in 6 tries
# Failed at finding iodic in 6 tries
# Failed at finding ruder in 6 tries
# Failed at finding peats in 6 tries
# Failed at finding blurb in 6 tries
# Failed at finding asker in 6 tries
# Failed at finding jerks in 6 tries
# Failed at finding shush in 6 tries
# Failed at finding peals in 6 tries
# Failed at finding ravel in 6 tries
# Failed at finding redly in 6 tries
# Failed at finding wests in 6 tries
# Failed at finding crack in 6 tries
# Failed at finding motif in 6 tries
# Failed at finding feted in 6 tries
# Failed at finding gazes in 6 tries
# Failed at finding ducks in 6 tries
# Failed at finding whine in 6 tries
# Failed at finding harms in 6 tries
# Failed at finding cruft in 6 tries
# Failed at finding galls in 6 tries
# Failed at finding edify in 6 tries
# Failed at finding tolls in 6 tries
# Failed at finding gibes in 6 tries
# Failed at finding lambs in 6 tries
# Failed at finding looks in 6 tries
# Failed at finding duchy in 6 tries
# Failed at finding zloty in 6 tries
# Failed at finding gongs in 6 tries
# Failed at finding billy in 6 tries
# Failed at finding vales in 6 tries
# Failed at finding oxlip in 6 tries
# Failed at finding irked in 6 tries
# Failed at finding loins in 6 tries
# Failed at finding stray in 6 tries
# Failed at finding value in 6 tries
# Failed at finding boner in 6 tries
# Failed at finding cruet in 6 tries
# Failed at finding isles in 6 tries
# Failed at finding lemme in 6 tries
# Failed at finding butts in 6 tries
# Failed at finding dream in 6 tries
# Failed at finding clams in 6 tries
# Failed at finding swede in 6 tries
# Failed at finding ruses in 6 tries
# Failed at finding bared in 6 tries
# Failed at finding frizz in 6 tries
# Failed at finding vigor in 6 tries
# Failed at finding spits in 6 tries
# Failed at finding screw in 6 tries
# Failed at finding waits in 6 tries
# Failed at finding shams in 6 tries
# Failed at finding trios in 6 tries
# Failed at finding peeve in 6 tries
# Failed at finding yield in 6 tries
# Failed at finding uncap in 6 tries
# Failed at finding coops in 6 tries
# Failed at finding chalk in 6 tries
# Failed at finding flaks in 6 tries
# Failed at finding metes in 6 tries
# Failed at finding share in 6 tries
# Failed at finding worts in 6 tries
# Failed at finding muted in 6 tries
# Failed at finding about in 6 tries
# Failed at finding bless in 6 tries
# Failed at finding cress in 6 tries
# Failed at finding soars in 6 tries
# Failed at finding banjo in 6 tries
# Failed at finding liker in 6 tries
# Failed at finding loops in 6 tries
# Failed at finding admen in 6 tries
# Failed at finding klieg in 6 tries
# Failed at finding direr in 6 tries
# Failed at finding edify in 6 tries
# Failed at finding spank in 6 tries
# Failed at finding prior in 6 tries
# Failed at finding nears in 6 tries
# Failed at finding fizzy in 6 tries
# Failed at finding ember in 6 tries
# Failed at finding xerox in 6 tries
# Failed at finding frizz in 6 tries
# Failed at finding ichor in 6 tries
# Failed at finding injun in 6 tries
# Failed at finding kluge in 6 tries
# Failed at finding bongs in 6 tries
# Failed at finding okays in 6 tries
# Failed at finding folia in 6 tries
# Failed at finding gouda in 6 tries
# Failed at finding genie in 6 tries
# Failed at finding egret in 6 tries
# Failed at finding pours in 6 tries
# Failed at finding dowry in 6 tries
# Failed at finding waltz in 6 tries
# Failed at finding track in 6 tries
# Failed at finding keyer in 6 tries
# Failed at finding scion in 6 tries
# Failed at finding thumb in 6 tries
# Failed at finding vogue in 6 tries
# Failed at finding hempy in 6 tries
# Failed at finding hooch in 6 tries
# Failed at finding stead in 6 tries
# Failed at finding inapt in 6 tries
# Failed at finding lymph in 6 tries
# Failed at finding sheaf in 6 tries
# Failed at finding happy in 6 tries
# Failed at finding goads in 6 tries
# Failed at finding ichor in 6 tries
# Failed at finding wench in 6 tries
# Failed at finding first in 6 tries
# Failed at finding gulls in 6 tries
# Failed at finding pupil in 6 tries
# Failed at finding chief in 6 tries
# Failed at finding zooms in 6 tries
# Failed at finding chewy in 6 tries
# Failed at finding janes in 6 tries
# Failed at finding shiki in 6 tries
# Failed at finding wrung in 6 tries
# Failed at finding tufty in 6 tries
# Failed at finding savvy in 6 tries
# Failed at finding rawer in 6 tries
# Failed at finding taste in 6 tries
# Failed at finding dribs in 6 tries
# Failed at finding saucy in 6 tries
# Failed at finding loath in 6 tries
# Failed at finding snide in 6 tries
# Failed at finding unjam in 6 tries
# Failed at finding iotas in 6 tries
# Failed at finding kinds in 6 tries
# Failed at finding elect in 6 tries
# Failed at finding penal in 6 tries
# Failed at finding sense in 6 tries
# Failed at finding enrol in 6 tries
# Failed at finding coper in 6 tries
# Failed at finding thumb in 6 tries
# Failed at finding giant in 6 tries
# Failed at finding board in 6 tries
# Failed at finding serum in 6 tries
# Failed at finding inept in 6 tries
# Failed at finding dully in 6 tries
# Failed at finding match in 6 tries
# Failed at finding souse in 6 tries
# Failed at finding pubic in 6 tries
# Failed at finding sonny in 6 tries
# Failed at finding woods in 6 tries
# Failed at finding ioctl in 6 tries
# Failed at finding lousy in 6 tries
# Failed at finding vagus in 6 tries
# Failed at finding bases in 6 tries
# Failed at finding bahts in 6 tries
# Failed at finding boozy in 6 tries
# Failed at finding banks in 6 tries
# Failed at finding beard in 6 tries
# Failed at finding dudes in 6 tries
# Failed at finding velar in 6 tries
# Failed at finding bloke in 6 tries
# Failed at finding strap in 6 tries
# Failed at finding pacer in 6 tries
# Failed at finding kicks in 6 tries
# Failed at finding puked in 6 tries
# Failed at finding scuff in 6 tries
# Failed at finding bibbs in 6 tries
# Failed at finding creek in 6 tries
# Failed at finding warms in 6 tries
# Failed at finding tales in 6 tries
# Failed at finding voids in 6 tries
# Failed at finding boars in 6 tries
# Failed at finding butyl in 6 tries
# Failed at finding roble in 6 tries
# Failed at finding wimpy in 6 tries
# Failed at finding unhip in 6 tries
# Failed at finding leapt in 6 tries
# Failed at finding snark in 6 tries
# Failed at finding anvil in 6 tries
# Failed at finding epics in 6 tries
# Failed at finding glade in 6 tries
# Failed at finding blind in 6 tries
# Failed at finding grout in 6 tries
# Failed at finding faint in 6 tries
# Failed at finding flams in 6 tries
# Failed at finding think in 6 tries
# Failed at finding spear in 6 tries
# Failed at finding chain in 6 tries
# Failed at finding rodeo in 6 tries
# Failed at finding randy in 6 tries
# Failed at finding bloat in 6 tries
# Failed at finding aural in 6 tries
# Failed at finding limbs in 6 tries
# Failed at finding excon in 6 tries
# Failed at finding gibed in 6 tries
# Failed at finding handy in 6 tries
# Failed at finding macho in 6 tries
# Failed at finding sally in 6 tries
# Failed at finding swash in 6 tries
# Failed at finding stead in 6 tries
# Failed at finding waker in 6 tries
# Failed at finding novas in 6 tries
# Failed at finding styes in 6 tries
# Failed at finding brats in 6 tries
# Failed at finding raves in 6 tries
# Failed at finding bison in 6 tries
# Failed at finding micks in 6 tries
# Failed at finding skiff in 6 tries
# Failed at finding junks in 6 tries
# Failed at finding stout in 6 tries
# Failed at finding bated in 6 tries
# Failed at finding begot in 6 tries
# Failed at finding howls in 6 tries
# Failed at finding above in 6 tries
# Failed at finding axmen in 6 tries
# Failed at finding plays in 6 tries
# Failed at finding rogue in 6 tries
# Failed at finding dorms in 6 tries
# Failed at finding axial in 6 tries
# Failed at finding wince in 6 tries
# Failed at finding beans in 6 tries
# Failed at finding smack in 6 tries
# Failed at finding pulls in 6 tries
# Failed at finding fried in 6 tries
# Failed at finding disks in 6 tries
# Failed at finding spank in 6 tries
# Failed at finding cabal in 6 tries
# Failed at finding polio in 6 tries
# Failed at finding vizor in 6 tries
# Failed at finding bogey in 6 tries
# Failed at finding duped in 6 tries
# Failed at finding fondu in 6 tries
# Failed at finding veldt in 6 tries
# Failed at finding mitts in 6 tries
# Failed at finding braid in 6 tries
# Failed at finding refer in 6 tries
# Failed at finding black in 6 tries
# Failed at finding dicky in 6 tries
# Failed at finding tufts in 6 tries
# Failed at finding musks in 6 tries
# Failed at finding louts in 6 tries
# Failed at finding askew in 6 tries
# Failed at finding gelds in 6 tries
# Failed at finding chair in 6 tries
# Failed at finding flush in 6 tries
# Failed at finding scone in 6 tries
# Failed at finding dives in 6 tries
# Failed at finding nudie in 6 tries
# Failed at finding lacer in 6 tries
# Failed at finding gaunt in 6 tries
# Failed at finding rarer in 6 tries
# Failed at finding duped in 6 tries
# Failed at finding deism in 6 tries
# Failed at finding legal in 6 tries
# Failed at finding alkyd in 6 tries
# Failed at finding arose in 6 tries
# Failed at finding sedge in 6 tries
# Failed at finding brawn in 6 tries
# Failed at finding twirl in 6 tries
# Failed at finding blini in 6 tries
# Failed at finding arson in 6 tries
# Failed at finding dingy in 6 tries
# Failed at finding murky in 6 tries
# Failed at finding rumps in 6 tries
# Failed at finding fresh in 6 tries
# Failed at finding whore in 6 tries
# Failed at finding  in 6 tries
# Failed at finding lands in 6 tries
# Failed at finding wedgy in 6 tries
# Failed at finding loath in 6 tries
# Failed at finding flail in 6 tries
# Failed at finding films in 6 tries
# Failed at finding pinko in 6 tries
# Failed at finding taros in 6 tries
# Failed at finding specs in 6 tries
# Failed at finding miles in 6 tries
# Failed at finding snugs in 6 tries
# Failed at finding kappa in 6 tries
# Failed at finding bacon in 6 tries
# Failed at finding soaps in 6 tries
# Failed at finding veils in 6 tries
# Failed at finding hayed in 6 tries
# Failed at finding edger in 6 tries
# Failed at finding clays in 6 tries
# Failed at finding icing in 6 tries
# Failed at finding adobe in 6 tries
# Failed at finding caddy in 6 tries
# Failed at finding stoic in 6 tries
# Failed at finding track in 6 tries
# Failed at finding dinar in 6 tries
# Failed at finding hames in 6 tries
# Failed at finding edges in 6 tries
# Failed at finding palms in 6 tries
# Failed at finding wifey in 6 tries
# Failed at finding rains in 6 tries
# Failed at finding foxed in 6 tries
# Failed at finding soppy in 6 tries
# Failed at finding barfy in 6 tries
# Failed at finding diest in 6 tries
# Failed at finding lodge in 6 tries
# Failed at finding holey in 6 tries
# Failed at finding roods in 6 tries
# Failed at finding linty in 6 tries
# Failed at finding slump in 6 tries
# Failed at finding clout in 6 tries
# Failed at finding epoxy in 6 tries
# Failed at finding muons in 6 tries
# Failed at finding spray in 6 tries
# Failed at finding boxed in 6 tries
# Failed at finding cacao in 6 tries
# Failed at finding shout in 6 tries
# Failed at finding versa in 6 tries
# Failed at finding hotel in 6 tries
# Failed at finding clime in 6 tries
# Failed at finding hiked in 6 tries
# Failed at finding abuse in 6 tries
# Failed at finding bulge in 6 tries
# Failed at finding drily in 6 tries
# Failed at finding caves in 6 tries
# Failed at finding axing in 6 tries
# Failed at finding furze in 6 tries
# Failed at finding burns in 6 tries
# Failed at finding lieth in 6 tries
# Failed at finding niche in 6 tries
# Failed at finding veers in 6 tries
# Failed at finding sable in 6 tries
# Failed at finding teens in 6 tries
# Failed at finding crept in 6 tries
# Failed at finding vases in 6 tries
# Failed at finding preen in 6 tries
# Failed at finding aleph in 6 tries
# Failed at finding sworn in 6 tries
# Failed at finding folky in 6 tries
# Failed at finding wrist in 6 tries
# Failed at finding bones in 6 tries
# Failed at finding vodka in 6 tries
# Failed at finding conga in 6 tries
# Failed at finding miner in 6 tries
# Failed at finding laser in 6 tries
# Failed at finding beaux in 6 tries
# Failed at finding klugy in 6 tries
# Failed at finding resew in 6 tries
# Failed at finding sicks in 6 tries
# Failed at finding doges in 6 tries
# Failed at finding barfy in 6 tries
# Failed at finding elect in 6 tries
# Failed at finding kayos in 6 tries
# Failed at finding gilts in 6 tries
# Failed at finding scope in 6 tries
# Failed at finding bided in 6 tries
# Failed at finding glare in 6 tries
# Failed at finding pater in 6 tries
# Failed at finding extra in 6 tries
# Failed at finding doffs in 6 tries
# Failed at finding pelts in 6 tries
# Failed at finding matte in 6 tries
# Failed at finding cults in 6 tries
# Failed at finding curly in 6 tries
# Failed at finding optic in 6 tries
# Failed at finding largo in 6 tries
# Failed at finding house in 6 tries
# Failed at finding rutty in 6 tries
# Failed at finding coven in 6 tries
# Failed at finding vista in 6 tries
# Failed at finding react in 6 tries
# Failed at finding mauve in 6 tries
# Failed at finding sigma in 6 tries
# Failed at finding yurts in 6 tries
# Failed at finding genus in 6 tries
# Failed at finding gangs in 6 tries
# Failed at finding elves in 6 tries
# Failed at finding ghost in 6 tries
# Failed at finding ruffs in 6 tries
# Failed at finding pulps in 6 tries
# Failed at finding duals in 6 tries
# Failed at finding havoc in 6 tries
# Failed at finding teary in 6 tries
# Failed at finding oaten in 6 tries
# Failed at finding hunks in 6 tries
# Failed at finding jiber in 6 tries
# Failed at finding punts in 6 tries
# Failed at finding takes in 6 tries
# Failed at finding surge in 6 tries
# Failed at finding kiosk in 6 tries
# Failed at finding bigly in 6 tries
# Failed at finding goyim in 6 tries
# Failed at finding cough in 6 tries
# Failed at finding quiff in 6 tries
# Failed at finding newly in 6 tries
# Failed at finding spoon in 6 tries
# Failed at finding attar in 6 tries
# Failed at finding drums in 6 tries
# Failed at finding chant in 6 tries
# Failed at finding gonzo in 6 tries
# Failed at finding hands in 6 tries
# Failed at finding aster in 6 tries
# Failed at finding conch in 6 tries
# Failed at finding gamey in 6 tries
# Failed at finding bonny in 6 tries
# Failed at finding yoyos in 6 tries
# Failed at finding riled in 6 tries
# Failed at finding echos in 6 tries
# Failed at finding feued in 6 tries
# Failed at finding bards in 6 tries
# Failed at finding trunk in 6 tries
# Failed at finding claps in 6 tries
# Failed at finding teals in 6 tries
# Failed at finding whomp in 6 tries
# Failed at finding pimps in 6 tries
# Failed at finding klugy in 6 tries
# Failed at finding stoic in 6 tries
# Failed at finding gipsy in 6 tries
# Failed at finding faxes in 6 tries
# Failed at finding coxed in 6 tries
# Failed at finding tunas in 6 tries
# Failed at finding putty in 6 tries
# Failed at finding laude in 6 tries
# Failed at finding soles in 6 tries
# Failed at finding sound in 6 tries
# Failed at finding blobs in 6 tries
# Failed at finding shale in 6 tries
# Failed at finding snuck in 6 tries
# Failed at finding hated in 6 tries
# Failed at finding wheal in 6 tries
# Failed at finding poise in 6 tries
# Failed at finding sprig in 6 tries
# Failed at finding flake in 6 tries
# Failed at finding lease in 6 tries
# Failed at finding blast in 6 tries
# Failed at finding vends in 6 tries
# Failed at finding brags in 6 tries
# Failed at finding aurae in 6 tries
# Failed at finding plunk in 6 tries
# Failed at finding deary in 6 tries
# Failed at finding store in 6 tries
# Failed at finding sixes in 6 tries
# Failed at finding mired in 6 tries
# Failed at finding chaps in 6 tries
# Failed at finding docks in 6 tries
# Failed at finding cawed in 6 tries
# Failed at finding corps in 6 tries
# Failed at finding tunas in 6 tries
# Failed at finding aorta in 6 tries
# Failed at finding poohs in 6 tries
# Failed at finding butch in 6 tries
# Failed at finding gimel in 6 tries
# Failed at finding aping in 6 tries
# Failed at finding amahs in 6 tries
# Failed at finding ranks in 6 tries
# Failed at finding thrum in 6 tries
# Failed at finding jolts in 6 tries
# Failed at finding wears in 6 tries
# Failed at finding clock in 6 tries
# Failed at finding moths in 6 tries
# Failed at finding merse in 6 tries
# Failed at finding togas in 6 tries
# Failed at finding dusty in 6 tries
# Failed at finding zowie in 6 tries
# Failed at finding roped in 6 tries
# Failed at finding tower in 6 tries
# Failed at finding trews in 6 tries
# Failed at finding topes in 6 tries
# Failed at finding booms in 6 tries
# Failed at finding chink in 6 tries
# Failed at finding bayed in 6 tries
# Failed at finding poste in 6 tries
# Failed at finding waspy in 6 tries
# Failed at finding villi in 6 tries
# Failed at finding dicot in 6 tries
# Failed at finding dozer in 6 tries
# Failed at finding reeve in 6 tries
# Failed at finding ethyl in 6 tries
# Failed at finding tizzy in 6 tries
# Failed at finding talky in 6 tries
# Failed at finding fates in 6 tries
# Failed at finding combs in 6 tries
# Failed at finding sushi in 6 tries
# Failed at finding axels in 6 tries
# Failed at finding dhows in 6 tries
# Failed at finding penal in 6 tries
# Failed at finding decry in 6 tries
# Failed at finding epees in 6 tries
# Failed at finding aegis in 6 tries
# Failed at finding ameba in 6 tries
# Failed at finding imbed in 6 tries
# Failed at finding bands in 6 tries
# Failed at finding calyx in 6 tries
# Failed at finding belch in 6 tries
# Failed at finding blurs in 6 tries
# Failed at finding saint in 6 tries
# Failed at finding women in 6 tries
# Failed at finding ducky in 6 tries
# Failed at finding cinch in 6 tries
# Failed at finding crate in 6 tries
# Failed at finding russe in 6 tries
# Failed at finding freak in 6 tries
# Failed at finding glens in 6 tries
# Failed at finding beery in 6 tries
# Failed at finding foals in 6 tries
# Failed at finding sized in 6 tries
# Failed at finding cameo in 6 tries
# Failed at finding bunny in 6 tries
# Failed at finding fudgy in 6 tries
# Failed at finding flics in 6 tries
# Failed at finding deuce in 6 tries
# Failed at finding whole in 6 tries
# Failed at finding haiku in 6 tries
# Failed at finding loyal in 6 tries
# Failed at finding swank in 6 tries
# Failed at finding kivas in 6 tries
# Failed at finding pleas in 6 tries
# Failed at finding axiom in 6 tries
# Failed at finding space in 6 tries
# Failed at finding loots in 6 tries
# Failed at finding pager in 6 tries
# Failed at finding bouts in 6 tries
# Failed at finding dower in 6 tries
# Failed at finding plumy in 6 tries
# Failed at finding flams in 6 tries
# Failed at finding mayor in 6 tries
# Failed at finding musos in 6 tries
# Failed at finding sylph in 6 tries
# Failed at finding sputa in 6 tries
# Failed at finding manic in 6 tries
# Failed at finding evens in 6 tries
# Failed at finding yummy in 6 tries
# Failed at finding rebid in 6 tries
# Failed at finding craps in 6 tries
# Failed at finding tipsy in 6 tries
# Failed at finding heels in 6 tries
# Failed at finding boost in 6 tries
# Failed at finding popes in 6 tries
# Failed at finding urges in 6 tries
# Failed at finding liter in 6 tries
# Failed at finding mungy in 6 tries
# Failed at finding spiel in 6 tries
# Failed at finding piing in 6 tries
# Failed at finding scuds in 6 tries
# Failed at finding deque in 6 tries
# Failed at finding wiper in 6 tries
# Failed at finding newsy in 6 tries
# Failed at finding newel in 6 tries
# Failed at finding gilds in 6 tries
# Failed at finding scope in 6 tries
# Failed at finding sates in 6 tries
# Failed at finding poles in 6 tries
# Failed at finding whale in 6 tries
# Failed at finding petal in 6 tries
# Failed at finding thief in 6 tries
# Failed at finding aging in 6 tries
# Failed at finding peens in 6 tries
# Failed at finding sleet in 6 tries
# Failed at finding yikes in 6 tries
# Failed at finding ocean in 6 tries
# Failed at finding cohos in 6 tries
# Failed at finding unfix in 6 tries
# Failed at finding lased in 6 tries
# Failed at finding foots in 6 tries
# Failed at finding space in 6 tries
# Failed at finding radon in 6 tries
# Failed at finding shmoo in 6 tries
# Failed at finding pooey in 6 tries
# Failed at finding amour in 6 tries
# Failed at finding troll in 6 tries
# Failed at finding fears in 6 tries
# Failed at finding toked in 6 tries
# Failed at finding poufs in 6 tries
# Failed at finding glens in 6 tries
# Failed at finding flunk in 6 tries
# Failed at finding bouts in 6 tries
# Failed at finding label in 6 tries
# Failed at finding bison in 6 tries
# Failed at finding tepee in 6 tries
# Failed at finding creed in 6 tries
# Failed at finding cored in 6 tries
# Failed at finding pumps in 6 tries
# Failed at finding gages in 6 tries
# Failed at finding freak in 6 tries
# Failed at finding purse in 6 tries
# Failed at finding stink in 6 tries
# Failed at finding poste in 6 tries
# Failed at finding apish in 6 tries
# Failed at finding groat in 6 tries
# Failed at finding rolls in 6 tries
# Failed at finding imago in 6 tries
# Failed at finding heave in 6 tries
# Failed at finding hicks in 6 tries
# Failed at finding whore in 6 tries
# Failed at finding wahoo in 6 tries
# Failed at finding blear in 6 tries
# Failed at finding mimic in 6 tries
# Failed at finding lulus in 6 tries
# Failed at finding recto in 6 tries
# Failed at finding sends in 6 tries
# Failed at finding quoit in 6 tries
# Failed at finding buses in 6 tries
# Failed at finding spicy in 6 tries
# Failed at finding doser in 6 tries
# Failed at finding laver in 6 tries
# Failed at finding panty in 6 tries
# Failed at finding typed in 6 tries
# Failed at finding snags in 6 tries
# Failed at finding found in 6 tries
# Failed at finding clasp in 6 tries
# Failed at finding uncap in 6 tries
# Failed at finding varia in 6 tries
# Failed at finding snout in 6 tries
# Failed at finding cuber in 6 tries
# Failed at finding stets in 6 tries
# Failed at finding valve in 6 tries
# Failed at finding crony in 6 tries
# Failed at finding unate in 6 tries
# Failed at finding miser in 6 tries
# Failed at finding mucks in 6 tries
# Failed at finding tends in 6 tries
# Failed at finding bathe in 6 tries
# Failed at finding whooo in 6 tries
# Failed at finding dungs in 6 tries
# Failed at finding owned in 6 tries
# Failed at finding amens in 6 tries
# Failed at finding taels in 6 tries
# Failed at finding fader in 6 tries
# Failed at finding shank in 6 tries
# Failed at finding waled in 6 tries
# Failed at finding swags in 6 tries
# Failed at finding mazer in 6 tries
# Failed at finding ripen in 6 tries
# Failed at finding beats in 6 tries
# Failed at finding mimic in 6 tries
# Failed at finding hours in 6 tries
# Failed at finding caulk in 6 tries
# Failed at finding titer in 6 tries
# Failed at finding mater in 6 tries
# Failed at finding narco in 6 tries
# Failed at finding poems in 6 tries
# Failed at finding dolor in 6 tries
# Failed at finding croak in 6 tries
# Failed at finding natch in 6 tries
# Failed at finding loggy in 6 tries
# Failed at finding fitly in 6 tries
# Failed at finding urges in 6 tries
# Failed at finding kelly in 6 tries
# Failed at finding tiled in 6 tries
# Failed at finding onset in 6 tries
# Failed at finding zombi in 6 tries
# Failed at finding amply in 6 tries
# Failed at finding loafs in 6 tries
# Failed at finding hilly in 6 tries
# Failed at finding sonic in 6 tries
# Failed at finding apnea in 6 tries
# Failed at finding amber in 6 tries
# Failed at finding snake in 6 tries
# Failed at finding modes in 6 tries
# Failed at finding steel in 6 tries
# Failed at finding loped in 6 tries
# Failed at finding toast in 6 tries
# Failed at finding crazy in 6 tries
# Failed at finding limbs in 6 tries
# Failed at finding scams in 6 tries
# Failed at finding ember in 6 tries
# Failed at finding okays in 6 tries
# Failed at finding caged in 6 tries
# Failed at finding breve in 6 tries
# Failed at finding tapes in 6 tries
# Failed at finding epact in 6 tries
# Failed at finding booed in 6 tries
# Failed at finding peeps in 6 tries
# Failed at finding vases in 6 tries
# Failed at finding loams in 6 tries
# Failed at finding thumb in 6 tries
# Failed at finding colts in 6 tries
# Failed at finding flied in 6 tries
# Failed at finding lubes in 6 tries
# Failed at finding topic in 6 tries
# Failed at finding muter in 6 tries
# Failed at finding oaken in 6 tries
# Failed at finding toted in 6 tries
# Failed at finding twigs in 6 tries
# Failed at finding exact in 6 tries
# Failed at finding tufas in 6 tries
# Failed at finding thunk in 6 tries
# Failed at finding manse in 6 tries
# Failed at finding siege in 6 tries
# Failed at finding ayins in 6 tries
# Failed at finding gunny in 6 tries
# Failed at finding egret in 6 tries
# Failed at finding vises in 6 tries
# Failed at finding baron in 6 tries
# Failed at finding noble in 6 tries
# Failed at finding frogs in 6 tries
# Failed at finding indie in 6 tries
# Failed at finding costs in 6 tries
# Failed at finding mills in 6 tries
# Failed at finding navel in 6 tries
# Failed at finding shins in 6 tries
# Failed at finding cites in 6 tries
# Failed at finding carpy in 6 tries
# Failed at finding fulls in 6 tries
# Failed at finding belts in 6 tries
# Failed at finding spunk in 6 tries
# Failed at finding taels in 6 tries
# Failed at finding boded in 6 tries
# Failed at finding decal in 6 tries
# Failed at finding chino in 6 tries
# Failed at finding biddy in 6 tries
# Failed at finding forky in 6 tries
# Failed at finding seedy in 6 tries
# Failed at finding loggy in 6 tries
# Failed at finding ploys in 6 tries
# Failed at finding beard in 6 tries
# Failed at finding gravy in 6 tries
# Failed at finding botch in 6 tries
# Failed at finding ponds in 6 tries
# Failed at finding huffy in 6 tries
# Failed at finding hafta in 6 tries
# Failed at finding typed in 6 tries
# Failed at finding goods in 6 tries
# Failed at finding roomy in 6 tries
# Failed at finding diazo in 6 tries
# Failed at finding input in 6 tries
# Failed at finding decay in 6 tries
# Failed at finding fenny in 6 tries
# Failed at finding hardy in 6 tries
# Failed at finding borer in 6 tries
# Failed at finding vivre in 6 tries
# Failed at finding dents in 6 tries
# Failed at finding corky in 6 tries
# Failed at finding reman in 6 tries
# Failed at finding flung in 6 tries
# Failed at finding bigot in 6 tries
# Failed at finding canal in 6 tries
# Failed at finding blurt in 6 tries
# Failed at finding colic in 6 tries
# Failed at finding squab in 6 tries
# Failed at finding traps in 6 tries
# Failed at finding unfix in 6 tries
# Failed at finding comfy in 6 tries
# Failed at finding retry in 6 tries
# Failed at finding dazes in 6 tries
# Failed at finding melon in 6 tries
# Failed at finding wanly in 6 tries
# Failed at finding grunt in 6 tries
# Failed at finding ruder in 6 tries
# Failed at finding freed in 6 tries
# Failed at finding chili in 6 tries
# Failed at finding crocs in 6 tries
# Failed at finding podia in 6 tries
# Failed at finding blunt in 6 tries
# Failed at finding curbs in 6 tries
# Failed at finding tufty in 6 tries
# Failed at finding chink in 6 tries
# Failed at finding dribs in 6 tries
# Failed at finding slime in 6 tries
# Failed at finding gator in 6 tries
# Failed at finding ankhs in 6 tries
# Failed at finding faith in 6 tries
# Failed at finding spoon in 6 tries
# Failed at finding rogue in 6 tries
# Failed at finding gimpy in 6 tries
# Failed at finding lisle in 6 tries
# Failed at finding woofs in 6 tries
# Failed at finding clods in 6 tries
# Failed at finding abide in 6 tries
# Failed at finding tipsy in 6 tries
# Failed at finding ovens in 6 tries
# Failed at finding coxes in 6 tries
# Failed at finding barfy in 6 tries
# Failed at finding palmy in 6 tries
# Failed at finding arose in 6 tries
# Failed at finding bodes in 6 tries
# Failed at finding young in 6 tries
# Failed at finding wells in 6 tries
# Failed at finding acorn in 6 tries
# Failed at finding gumbo in 6 tries
# Failed at finding bumps in 6 tries
# Failed at finding bevel in 6 tries
# Failed at finding pupal in 6 tries
# Failed at finding discs in 6 tries
# Failed at finding pushy in 6 tries
# Failed at finding acted in 6 tries
# Failed at finding bleed in 6 tries
# Failed at finding wreak in 6 tries
# Failed at finding bawls in 6 tries
# Failed at finding tines in 6 tries
# Failed at finding kabob in 6 tries
# Failed at finding ferny in 6 tries
# Failed at finding facts in 6 tries
# Failed at finding baggy in 6 tries
# Failed at finding nutsy in 6 tries
# Failed at finding grace in 6 tries
# Failed at finding deism in 6 tries
# Failed at finding tents in 6 tries
# Failed at finding viand in 6 tries
# Failed at finding hydra in 6 tries
# Failed at finding woods in 6 tries
# Failed at finding gorse in 6 tries
# Failed at finding pupal in 6 tries
# Failed at finding shank in 6 tries
# Failed at finding curer in 6 tries
# Failed at finding masse in 6 tries
# Failed at finding frier in 6 tries
# Failed at finding blitz in 6 tries
# Failed at finding rebut in 6 tries
# Failed at finding power in 6 tries
# Failed at finding guide in 6 tries
# Failed at finding kiddo in 6 tries
# Failed at finding peons in 6 tries
# Failed at finding faxes in 6 tries
# Failed at finding reuse in 6 tries
# Failed at finding slaws in 6 tries
# Failed at finding firth in 6 tries
# Failed at finding trail in 6 tries
# Failed at finding dears in 6 tries
# Failed at finding amber in 6 tries
# Failed at finding dotes in 6 tries
# Failed at finding cairn in 6 tries
# Failed at finding forty in 6 tries
# Failed at finding touts in 6 tries
# Failed at finding frock in 6 tries
# Failed at finding giant in 6 tries
# Failed at finding grapy in 6 tries
# Failed at finding apply in 6 tries
# Failed at finding steam in 6 tries
# Failed at finding weird in 6 tries
# Failed at finding colas in 6 tries
# Failed at finding tumor in 6 tries
# Failed at finding hubba in 6 tries
# Failed at finding stags in 6 tries
# ...
# Failed at finding limbs in 6 tries
# Failed at finding salve in 6 tries
# Failed at finding typos in 6 tries
# Failed at finding steer in 6 tries
# Failed at finding topos in 6 tries
# Failed at finding chins in 6 tries
# Failed at finding dooms in 6 tries
# Failed at finding amyls in 6 tries
# Failed at finding clean in 6 tries
# Failed at finding fecal in 6 tries
# Failed at finding slang in 6 tries
# Failed at finding wacky in 6 tries
# Failed at finding toyed in 6 tries
# Failed at finding lairs in 6 tries
# Failed at finding cluck in 6 tries
# Failed at finding deism in 6 tries
# Failed at finding sieve in 6 tries
# Failed at finding goosy in 6 tries
# Failed at finding lordy in 6 tries
# Failed at finding flour in 6 tries
# Failed at finding dyers in 6 tries
# Failed at finding fuzed in 6 tries
# Failed at finding twirp in 6 tries
# Failed at finding stoic in 6 tries
# Failed at finding zonal in 6 tries
# Failed at finding sweat in 6 tries
# Failed at finding nudie in 6 tries
# Failed at finding amaze in 6 tries
# Failed at finding smart in 6 tries
# Failed at finding actor in 6 tries
# Failed at finding pesky in 6 tries
# Failed at finding valid in 6 tries
# Failed at finding minis in 6 tries
# Failed at finding bilks in 6 tries
# Failed at finding sexed in 6 tries
# Failed at finding rawer in 6 tries
# Failed at finding cotta in 6 tries
# Failed at finding jeans in 6 tries
# Failed at finding timed in 6 tries
# Failed at finding gizmo in 6 tries
# Failed at finding still in 6 tries
# Failed at finding pixel in 6 tries
# Failed at finding whoas in 6 tries
# Failed at finding goyim in 6 tries
# Failed at finding ticks in 6 tries
# Failed at finding redox in 6 tries
# Failed at finding weave in 6 tries
# Failed at finding nimbi in 6 tries
# Failed at finding blank in 6 tries
# Failed at finding toady in 6 tries
# Failed at finding buyer in 6 tries
# Failed at finding rebus in 6 tries
# Failed at finding frank in 6 tries
# Failed at finding chute in 6 tries
# Failed at finding yawns in 6 tries
# Failed at finding harpy in 6 tries
# Failed at finding flier in 6 tries
# Failed at finding septa in 6 tries
# Failed at finding heath in 6 tries
# Failed at finding guild in 6 tries
# Failed at finding ftped in 6 tries
# Failed at finding putts in 6 tries
# Failed at finding laver in 6 tries
# Failed at finding holon in 6 tries
# Failed at finding foals in 6 tries
# Failed at finding wrote in 6 tries
# Failed at finding yeast in 6 tries
# Failed at finding peons in 6 tries
# Failed at finding acorn in 6 tries
# Failed at finding yogis in 6 tries
# Failed at finding bigly in 6 tries
# Failed at finding flops in 6 tries
# Failed at finding mumbo in 6 tries
# Failed at finding loxes in 6 tries
# Failed at finding doggy in 6 tries
# Failed at finding riles in 6 tries
# Failed at finding stews in 6 tries
# Failed at finding based in 6 tries
# Failed at finding camps in 6 tries
# Failed at finding safer in 6 tries
# Failed at finding toyon in 6 tries
# Failed at finding doter in 6 tries
# Failed at finding crisp in 6 tries
# Failed at finding lofts in 6 tries
# Succeeded at finding damns in 6 tries
# Failed at finding damns in 6 tries
# Failed at finding flaps in 6 tries
# Failed at finding holed in 6 tries
# Failed at finding tabby in 6 tries
# Failed at finding batty in 6 tries
# Failed at finding whims in 6 tries
# Failed at finding erupt in 6 tries
# Failed at finding cloys in 6 tries
# Failed at finding vibes in 6 tries
# Failed at finding abaci in 6 tries
# Failed at finding liens in 6 tries
# Failed at finding cents in 6 tries
# Failed at finding sawed in 6 tries
# Failed at finding whirl in 6 tries
# Failed at finding mends in 6 tries
# Failed at finding wales in 6 tries
# Failed at finding blabs in 6 tries
# Failed at finding icing in 6 tries
# Failed at finding jumbo in 6 tries
# Failed at finding jails in 6 tries
# Failed at finding diode in 6 tries
# Failed at finding whips in 6 tries
# Failed at finding spell in 6 tries
# Failed at finding sling in 6 tries
# Failed at finding doser in 6 tries
# Failed at finding funny in 6 tries
# Failed at finding cairn in 6 tries
# Failed at finding folic in 6 tries
# Failed at finding repel in 6 tries
# Failed at finding foist in 6 tries
# Failed at finding coyer in 6 tries
# Failed at finding mutts in 6 tries
# Failed at finding villi in 6 tries
# Failed at finding elide in 6 tries
# Failed at finding grabs in 6 tries
# Failed at finding injun in 6 tries
# Failed at finding tiros in 6 tries
# Failed at finding swine in 6 tries
# Failed at finding reedy in 6 tries
# Failed at finding decry in 6 tries
# Failed at finding skirt in 6 tries
# Failed at finding polos in 6 tries
# Failed at finding gravy in 6 tries
# Failed at finding bikes in 6 tries
# Failed at finding pffft in 6 tries
# Failed at finding norms in 6 tries
# Failed at finding gayer in 6 tries
# Failed at finding immix in 6 tries
# Failed at finding suing in 6 tries
# Failed at finding hafts in 6 tries
# Failed at finding races in 6 tries
# Failed at finding ended in 6 tries
# Failed at finding spins in 6 tries
# Failed at finding tasty in 6 tries
# Failed at finding sugar in 6 tries
# Failed at finding puree in 6 tries
# Failed at finding whack in 6 tries
# Failed at finding vacua in 6 tries
# Failed at finding plied in 6 tries
# Failed at finding hafta in 6 tries
# Failed at finding pupal in 6 tries
# Failed at finding diets in 6 tries
# Failed at finding slime in 6 tries
# Failed at finding hiver in 6 tries
# Failed at finding spies in 6 tries
# Failed at finding queue in 6 tries
# Failed at finding tamer in 6 tries
# Failed at finding cools in 6 tries
# Failed at finding sexed in 6 tries
# Failed at finding mutts in 6 tries
# Failed at finding winds in 6 tries
# Failed at finding boggy in 6 tries
# Failed at finding fades in 6 tries
# Failed at finding video in 6 tries
# Failed at finding steer in 6 tries
# Failed at finding vests in 6 tries
# Failed at finding gongs in 6 tries
# Failed at finding aroma in 6 tries
# Failed at finding fulls in 6 tries
# Failed at finding unity in 6 tries
# Failed at finding coqui in 6 tries
# Failed at finding gusty in 6 tries
# Failed at finding jerry in 6 tries
# Failed at finding parse in 6 tries
# Failed at finding clerk in 6 tries
# Failed at finding stilt in 6 tries
# Failed at finding vents in 6 tries
# Failed at finding tawny in 6 tries
# Failed at finding razes in 6 tries
# Failed at finding scold in 6 tries
# Failed at finding oddly in 6 tries
# Failed at finding rages in 6 tries
# Failed at finding hirer in 6 tries
# Failed at finding lauds in 6 tries
# Failed at finding frill in 6 tries
# Failed at finding tangs in 6 tries
# Failed at finding bronx in 6 tries
# Failed at finding wakes in 6 tries
# Failed at finding mayor in 6 tries
# Failed at finding depot in 6 tries
# Failed at finding login in 6 tries
# Failed at finding boron in 6 tries
# Failed at finding paces in 6 tries
# Failed at finding smogs in 6 tries
# Failed at finding nerve in 6 tries
# Failed at finding duffs in 6 tries
# Failed at finding fares in 6 tries
# Failed at finding spics in 6 tries
# Failed at finding swoon in 6 tries
# Failed at finding vised in 6 tries
# Failed at finding clams in 6 tries
# Failed at finding treys in 6 tries
# Failed at finding unsew in 6 tries
# Failed at finding leave in 6 tries
# Failed at finding corny in 6 tries
# Failed at finding water in 6 tries
# Failed at finding blots in 6 tries
# Failed at finding titre in 6 tries
# Failed at finding carat in 6 tries
# Failed at finding flash in 6 tries
# Failed at finding thigh in 6 tries
# Failed at finding yowls in 6 tries
# Failed at finding stark in 6 tries
# Failed at finding bilge in 6 tries
# Failed at finding curvy in 6 tries
# Failed at finding kefir in 6 tries
# Failed at finding grins in 6 tries
# Failed at finding holly in 6 tries
# Failed at finding learn in 6 tries
# Failed at finding lumps in 6 tries
# Failed at finding peons in 6 tries
# Failed at finding beers in 6 tries
# Failed at finding darer in 6 tries
# Failed at finding ruins in 6 tries
# Failed at finding gamic in 6 tries
# Failed at finding irons in 6 tries
# Failed at finding feuds in 6 tries
# Failed at finding miles in 6 tries
# Failed at finding clash in 6 tries
# Failed at finding gluer in 6 tries
# Failed at finding saner in 6 tries
# Failed at finding cross in 6 tries
# Failed at finding tower in 6 tries
# Failed at finding raves in 6 tries
# Failed at finding sloth in 6 tries
# Failed at finding shave in 6 tries
# Failed at finding admen in 6 tries
# Failed at finding obits in 6 tries
# Failed at finding hoses in 6 tries
# Failed at finding guise in 6 tries
# Failed at finding mused in 6 tries
# Failed at finding lunge in 6 tries
# Failed at finding kazoo in 6 tries
# Failed at finding fared in 6 tries
# Failed at finding chins in 6 tries
# Failed at finding clefs in 6 tries
# Failed at finding plash in 6 tries
# Failed at finding emend in 6 tries
# Failed at finding nerve in 6 tries
# Failed at finding loyal in 6 tries
# Failed at finding taste in 6 tries
# Failed at finding shots in 6 tries
# Failed at finding solid in 6 tries
# Failed at finding rends in 6 tries
# Failed at finding fuels in 6 tries
# Failed at finding doges in 6 tries
# Failed at finding semen in 6 tries
# Failed at finding flirt in 6 tries
# Failed at finding gyved in 6 tries
# Failed at finding sworn in 6 tries
# Failed at finding throe in 6 tries
# Failed at finding cuppy in 6 tries
# Failed at finding dairy in 6 tries
# Failed at finding cheat in 6 tries
# Failed at finding canes in 6 tries
# Failed at finding oxide in 6 tries
# Failed at finding filly in 6 tries
# Failed at finding stuns in 6 tries
# Failed at finding fader in 6 tries
# Failed at finding waves in 6 tries
# Failed at finding bolls in 6 tries
# Failed at finding probe in 6 tries
# Failed at finding cooky in 6 tries
# Failed at finding zones in 6 tries
# Failed at finding trace in 6 tries
# Failed at finding color in 6 tries
# Failed at finding rooty in 6 tries
# Failed at finding valor in 6 tries
# Failed at finding swami in 6 tries
# Failed at finding rally in 6 tries
# Failed at finding fungo in 6 tries
# Failed at finding apian in 6 tries
# Failed at finding steal in 6 tries
# Failed at finding chins in 6 tries
# Failed at finding routs in 6 tries
# Failed at finding vinca in 6 tries
# Failed at finding runes in 6 tries
# Failed at finding edify in 6 tries
# Failed at finding tribe in 6 tries
# Failed at finding atlas in 6 tries
# Failed at finding baldy in 6 tries
# Failed at finding mushy in 6 tries
# Failed at finding civil in 6 tries
# Failed at finding coral in 6 tries
# Failed at finding dixit in 6 tries
# Failed at finding buoys in 6 tries
# Failed at finding print in 6 tries
# Failed at finding alarm in 6 tries
# Failed at finding cheat in 6 tries
# Failed at finding souse in 6 tries
# Failed at finding owing in 6 tries
# Failed at finding pluck in 6 tries
# Failed at finding dirks in 6 tries
# Failed at finding chugs in 6 tries
# Failed at finding sport in 6 tries
# Failed at finding sauce in 6 tries
# Failed at finding worse in 6 tries
# Failed at finding expos in 6 tries
# Failed at finding goals in 6 tries
# Failed at finding doozy in 6 tries
# Failed at finding lotta in 6 tries
# Failed at finding meter in 6 tries
# Failed at finding graph in 6 tries
# Failed at finding jolts in 6 tries
# Failed at finding hoots in 6 tries
# Failed at finding peril in 6 tries
# Failed at finding touts in 6 tries
# Failed at finding bowls in 6 tries
# Failed at finding sooth in 6 tries
# Failed at finding prams in 6 tries
# Failed at finding alkyl in 6 tries
# Failed at finding rules in 6 tries
# Failed at finding doggy in 6 tries
# Failed at finding clogs in 6 tries
# Failed at finding peats in 6 tries
# Failed at finding fader in 6 tries
# Failed at finding terry in 6 tries
# Failed at finding swats in 6 tries
# Failed at finding roams in 6 tries
# Failed at finding trays in 6 tries
# Failed at finding rower in 6 tries
# Failed at finding hover in 6 tries
# Failed at finding bribe in 6 tries
# Failed at finding maxis in 6 tries
# Failed at finding grime in 6 tries
# Failed at finding cargo in 6 tries
# Failed at finding coots in 6 tries
# Failed at finding salty in 6 tries
# Failed at finding flabs in 6 tries
# Failed at finding goons in 6 tries
# Failed at finding genes in 6 tries
# Failed at finding pudgy in 6 tries
# Failed at finding vulva in 6 tries
# Failed at finding loses in 6 tries
# Failed at finding creak in 6 tries
# Failed at finding hands in 6 tries
# Failed at finding perch in 6 tries
# Failed at finding runty in 6 tries
# Failed at finding rabid in 6 tries
# Failed at finding rondo in 6 tries
# Failed at finding myrrh in 6 tries
# Failed at finding title in 6 tries
# Failed at finding coach in 6 tries
# Failed at finding darky in 6 tries
# Failed at finding coven in 6 tries
# Failed at finding cushy in 6 tries
# Failed at finding hicks in 6 tries
# Failed at finding loggy in 6 tries
# Failed at finding throw in 6 tries
# Failed at finding bloke in 6 tries
# Failed at finding gulls in 6 tries
# Failed at finding wends in 6 tries
# Failed at finding kenaf in 6 tries
# Failed at finding grate in 6 tries
# Failed at finding hirer in 6 tries
# Failed at finding crags in 6 tries
# Failed at finding lased in 6 tries
# Failed at finding toque in 6 tries
# Failed at finding opted in 6 tries
# Failed at finding amuse in 6 tries
# Failed at finding bents in 6 tries
# Failed at finding fined in 6 tries
# Failed at finding wades in 6 tries
# Failed at finding immix in 6 tries
# Failed at finding owner in 6 tries
# Failed at finding yummy in 6 tries
# Failed at finding cubit in 6 tries
# Failed at finding sorry in 6 tries
# Failed at finding freak in 6 tries
# Failed at finding timed in 6 tries
# Failed at finding dials in 6 tries
# Failed at finding mujik in 6 tries
# Failed at finding fanin in 6 tries
# Failed at finding noble in 6 tries
# Failed at finding woken in 6 tries
# Failed at finding erase in 6 tries
# Failed at finding stars in 6 tries
# Failed at finding fluid in 6 tries
# Failed at finding therm in 6 tries
# Failed at finding waker in 6 tries
# Failed at finding culls in 6 tries
# Failed at finding bayou in 6 tries
# Failed at finding adopt in 6 tries
# Failed at finding month in 6 tries
# Failed at finding spunk in 6 tries
# Failed at finding lousy in 6 tries
# Failed at finding beige in 6 tries
# Failed at finding lease in 6 tries
# Failed at finding hurry in 6 tries
# Failed at finding ducks in 6 tries
# Failed at finding revet in 6 tries
# Failed at finding links in 6 tries
# Failed at finding revet in 6 tries
# Failed at finding riots in 6 tries
# Failed at finding sulks in 6 tries
# Failed at finding teaks in 6 tries
# Failed at finding audit in 6 tries
# Failed at finding surge in 6 tries
# Failed at finding decay in 6 tries
# Failed at finding green in 6 tries
# Failed at finding lames in 6 tries
# Failed at finding tooth in 6 tries
# Failed at finding solid in 6 tries
# Failed at finding rises in 6 tries
# Failed at finding resin in 6 tries
# Failed at finding poops in 6 tries
# Failed at finding louse in 6 tries
# Failed at finding volts in 6 tries
# Failed at finding owner in 6 tries
# Failed at finding depot in 6 tries
# Failed at finding bares in 6 tries
# Failed at finding tutti in 6 tries
# Failed at finding apple in 6 tries
# Failed at finding felts in 6 tries
# Failed at finding psalm in 6 tries
# Failed at finding arity in 6 tries
# Failed at finding shale in 6 tries
# Failed at finding steps in 6 tries
# Failed at finding mouse in 6 tries
# Failed at finding sprue in 6 tries
# Failed at finding meted in 6 tries
# Failed at finding sumps in 6 tries
# Failed at finding might in 6 tries
# Failed at finding rhino in 6 tries
# Failed at finding darer in 6 tries
# Failed at finding torts in 6 tries
# Failed at finding grope in 6 tries
# Failed at finding whews in 6 tries
# Failed at finding moire in 6 tries
# Failed at finding bunko in 6 tries
# Failed at finding caved in 6 tries
# Failed at finding stela in 6 tries
# Failed at finding necks in 6 tries
# Failed at finding aegis in 6 tries
# Failed at finding maned in 6 tries
# Failed at finding sherd in 6 tries
# Failed at finding floor in 6 tries
# Failed at finding parch in 6 tries
# Failed at finding gills in 6 tries
# Failed at finding queue in 6 tries
# Failed at finding below in 6 tries
# Failed at finding dozen in 6 tries
# Failed at finding stoae in 6 tries
# Failed at finding leaky in 6 tries
# Failed at finding often in 6 tries
# Failed at finding honks in 6 tries
# Failed at finding stuns in 6 tries
# Failed at finding scuzz in 6 tries
# Failed at finding basal in 6 tries
# Failed at finding chirp in 6 tries
# Completed: 3 | Failed: 1997 | success_rate: 0.001500

# %%
l = [1,2,3,4,5]
s = ""
for i in range(100):
    idx = random.randint(0,len(l))
    s += str(idx)
    s += ","
s
# Out:
# '0,2,1,2,2,5,1,0,0,2,1,0,5,2,2,1,3,3,0,4,0,4,3,0,1,1,2,5,1,0,2,0,0,3,0,4,0,3,3,1,0,0,4,2,1,4,5,0,1,3,3,1,2,4,0,2,3,1,2,5,3,5,4,1,1,3,5,2,0,1,5,1,0,3,4,0,4,5,3,0,5,5,1,0,2,0,4,0,1,5,1,3,1,1,0,3,3,2,0,2,'
